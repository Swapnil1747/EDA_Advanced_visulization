# %%
import pandas as pd

# %%
data =pd.read_excel(r'C:\Users\swapn\Downloads\Movie-Rating.xlsx')

# %%
data
# Out:
#                      Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer     Comedy                         87
# 1             10,000 B.C.  Adventure                          9
# 2               12 Rounds     Action                         30
# 3               127 Hours  Adventure                         93
# 4                17 Again     Comedy                         55
# ..                    ...        ...                        ...
# 554         Your Highness     Comedy                         26
# 555       Youth in Revolt     Comedy                         68
# 556                Zodiac   Thriller                         89
# 557            Zombieland     Action                         90
# 558             Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(data)
# Out:
# 559

# %%
data.head()
# Out:
#                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer     Comedy                         87
# 1           10,000 B.C.  Adventure                          9
# 2             12 Rounds     Action                         30
# 3             127 Hours  Adventure                         93
# 4              17 Again     Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
data.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557       Zombieland    Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
data.columns =['Film','Genre','Criticrating','AudienceRating','BudgetMillions','Year']

# %%
data
# Out:
#                      Film      Genre  Criticrating  AudienceRating  \
# 0    (500) Days of Summer     Comedy            87              81
# 1             10,000 B.C.  Adventure             9              44
# 2               12 Rounds     Action            30              52
# 3               127 Hours  Adventure            93              84
# 4                17 Again     Comedy            55              70
# ..                    ...        ...           ...             ...
# 554         Your Highness     Comedy            26              36
# 555       Youth in Revolt     Comedy            68              52
# 556                Zodiac   Thriller            89              73
# 557            Zombieland     Action            90              87
# 558             Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
data.head()
# Out:
#                    Film      Genre  Criticrating  AudienceRating  \
# 0  (500) Days of Summer     Comedy            87              81
# 1           10,000 B.C.  Adventure             9              44
# 2             12 Rounds     Action            30              52
# 3             127 Hours  Adventure            93              84
# 4              17 Again     Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   Criticrating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
data.describe()
# Out:
#        Criticrating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
data['Film']
# Out:
# 0      (500) Days of Summer
# 1               10,000 B.C.
# 2                 12 Rounds
# 3                 127 Hours
# 4                  17 Again
#                ...
# 554           Your Highness
# 555         Youth in Revolt
# 556                  Zodiac
# 557              Zombieland
# 558               Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
data.Film
# Out:
# 0      (500) Days of Summer
# 1               10,000 B.C.
# 2                 12 Rounds
# 3                 127 Hours
# 4                  17 Again
#                ...
# 554           Your Highness
# 555         Youth in Revolt
# 556                  Zodiac
# 557              Zombieland
# 558               Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
data.Film =data.Film.astype('category')

# %%
data.Film
# Out:
# 0      (500) Days of Summer
# 1               10,000 B.C.
# 2                 12 Rounds
# 3                 127 Hours
# 4                  17 Again
#                ...
# 554           Your Highness
# 555         Youth in Revolt
# 556                  Zodiac
# 557              Zombieland
# 558               Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): [2012, '(500) Days of Summer', '10,000 B.C.', '12 Rounds', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland', 'Zookeeper']

# %%
data.head()
# Out:
#                    Film      Genre  Criticrating  AudienceRating  \
# 0  (500) Days of Summer     Comedy            87              81
# 1           10,000 B.C.  Adventure             9              44
# 2             12 Rounds     Action            30              52
# 3             127 Hours  Adventure            93              84
# 4              17 Again     Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   Criticrating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
data.Genre =data.Genre.astype('category')
data.Year = data.Year.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   Criticrating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
data.head()
# Out:
#                    Film      Genre  Criticrating  AudienceRating  \
# 0  (500) Days of Summer     Comedy            87              81
# 1           10,000 B.C.  Adventure             9              44
# 2             12 Rounds     Action            30              52
# 3             127 Hours  Adventure            93              84
# 4              17 Again     Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
data.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
data.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
data.describe()
# Out:
#        Criticrating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
data.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
# How to workking with join plot

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - bacically joint plot is a scatter plot & it find the relation b/w audience & critics
# - also if you look up you ccan find the uniform distribution (critics) and normal distribution (audience)

# %%
j = sns.jointplot(data =data,x ='Criticrating', y ='AudienceRating')
plt.show()
# Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating
# let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
j = sns.jointplot(data =data,x ='Criticrating', y ='AudienceRating',kind ='reg')
plt.show()

# %%
j = sns.jointplot(data =data,x ='Criticrating', y ='AudienceRating',kind='hex')
plt.show()

# %%
j = sns.jointplot(data =data,x ='Criticrating', y ='AudienceRating',kind='scatter')
plt.show()

# %%
j = sns.jointplot(data =data,x ='Criticrating', y ='AudienceRating',kind='kde')
plt.show()

# %%
m1 =sns.distplot(data.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2 =sns.distplot(data.AudienceRating ,bins=10)
plt.show()

# %%
n1 =sns.displot(data.AudienceRating,bins=15)
plt.show()

# %%
n1 = plt.hist(data.AudienceRating,bins=15)
plt.show()

# %%
sns.set_style('white')
n1 = plt.hist(data.AudienceRating,bins=20)
plt.show()

# %%
n1 =plt.hist(data.Criticrating	,bins=20)
plt.show()

# %%
# <<< chat -2

# Creating stacked histogram & this is bit toiugh to understasnd

# %%
h1 = plt.hist(data.BudgetMillions)
plt.show()

# %%
plt.hist(data[data.Genre =='Drama'].BudgetMillions)
plt.show()

# %%
plt.hist(data[data.Genre =='Action'].BudgetMillions)


plt.show()

# %%
plt.hist(data[data.Genre =='Comedy'].BudgetMillions)
plt.show()

# %%
plt.hist(data[data.Genre =='Horror'].BudgetMillions)
plt.show()

# %%
data.head()
# Out:
#                    Film      Genre  Criticrating  AudienceRating  \
# 0  (500) Days of Summer     Comedy            87              81
# 1           10,000 B.C.  Adventure             9              44
# 2             12 Rounds     Action            30              52
# 3             127 Hours  Adventure            93              84
# 4              17 Again     Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
data.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(data[data.Genre == 'Action'].BudgetMillions, bins = 20)
plt.hist(data[data.Genre == 'Thriller'].BudgetMillions, bins = 20)
plt.hist(data[data.Genre == 'Drama'].BudgetMillions, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([data[data.Genre == 'Action'].BudgetMillions,\
          data[data.Genre == 'Drama'].BudgetMillions, \
          data[data.Genre == 'Thriller'].BudgetMillions, \
          data[data.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in data.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 =sns.lmplot(data=data , x='Criticrating',y ='AudienceRating',fit_reg =True)
plt.show()

# %%
vis1 =sns.lmplot(data=data , x='Criticrating',y ='AudienceRating',fit_reg =False,hue='Genre')
plt.show()

# %%
vis1 =sns.lmplot(data=data,x='Criticrating',y='AudienceRating',fit_reg= False,hue='Genre',height=10,aspect=1)
plt.show()

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot

# %%
k1 = sns.kdeplot(data=data ,x='Criticrating' ,y ='AudienceRating')
plt.show()

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
sns.kdeplot(data = data, x = 'Criticrating' ,y = 'AudienceRating')
plt.show()

# %%
sns.kdeplot(data = data, x = 'Criticrating' ,y = 'AudienceRating',shade =True,shade_lowest =False,cmap='Reds')
plt.show()

# %%
sns.kdeplot(data = data, x = 'Criticrating' ,y = 'AudienceRating',shade_lowest =False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
sns.kdeplot(data = data, x = 'BudgetMillions' ,y = 'AudienceRating',shade =False,shade_lowest =False,cmap='Reds')
plt.show()

# %%
sns.set_style('dark')
sns.kdeplot(data = data, x = 'BudgetMillions' ,y = 'AudienceRating')
plt.show()

# %%
k2 =sns.kdeplot(data = data, x = 'BudgetMillions' ,y ='Criticrating')
plt.show()

# %%
f , ax = plt.subplots(1,2, figsize =(12,6))
plt.show()

# %%
f,ax=plt.subplots(3,3, figsize=(12,6))
plt.show()

# %%
f,ax = plt.subplots(1,2,figsize=(12,6))

k1 =sns.kdeplot(data = data, x = 'BudgetMillions' ,y = 'AudienceRating',ax =ax[0])
k2 =sns.kdeplot(data = data, x = 'BudgetMillions' ,y ='Criticrating',ax=ax[1])
plt.show()

# %%
ax
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='Criticrating'>],
#       dtype=object)

# %%
# Box plot-
w = sns.boxplot(data=data,x ='Genre',y='Criticrating')
plt.show()

# %%
# Violin plot 

x = sns.violinplot(data=data,x ='Genre',y='Criticrating')
plt.show()

# %%
w1 = sns.boxplot(data =data[data.Genre == 'Drama'], x='Year', y = 'Criticrating',hue='Genre')
plt.show()

# %%
w1 = sns.violinplot(data =data[data.Genre == 'Drama'], x='Year', y = 'Criticrating')
plt.show()

# %%
g =sns.FacetGrid (data, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots
plt.show()

# %%
plt.scatter(data.Criticrating,data.AudienceRating)
plt.show()

# %%
g =sns.FacetGrid (data, row = 'Genre', col = 'Year', hue = 'Genre')
g =g.map(plt.scatter,'Criticrating','AudienceRating')
plt.show()

# %%
g =sns.FacetGrid (data, row = 'Genre', col = 'Year', hue = 'Genre') 
g =g.map(plt.hist,'BudgetMillions')
plt.show()

# %%
g =sns.FacetGrid (data, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50,linewidth=0.5,edgecolor ='black')

g=g.map(plt.scatter,'Criticrating','AudienceRating',**kws)
plt.show()

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Corrected kdeplot calls
k1 = sns.kdeplot(data=data, x='BudgetMillions', y='AudienceRating', ax=axes[0, 0])
k2 = sns.kdeplot(data=data, x='BudgetMillions', y='Criticrating', ax=axes[0, 1])

k1.set(xlim=(-20, 160))
k2.set(xlim=(-20, 160))

# Violin plot
z = sns.violinplot(data=data[data.Genre == 'Drama'], x='Year', y='Criticrating', ax=axes[1, 0])

# Corrected kdeplot with shade
k4 = sns.kdeplot(data=data, x='Criticrating', y='AudienceRating', fill=True, cmap='Reds', ax=axes[1, 1])
k4b = sns.kdeplot(data=data, x='Criticrating', y='AudienceRating', cmap='Reds', ax=axes[1, 1])

plt.show()

# %%
# Set the style with custom background color
sns.set_style('dark', {'axes.facecolor': 'black'})

# Create a 2x2 subplot grid
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Plot [0,0]
k1 = sns.kdeplot(data=data, x='BudgetMillions', y='AudienceRating', 
                 fill=True, cmap='inferno', ax=axes[0, 0])
k1b = sns.kdeplot(data=data, x='BudgetMillions', y='AudienceRating', 
                  cmap='cool', ax=axes[0, 0])

# Plot [0,1]
k2 = sns.kdeplot(data=data, x='BudgetMillions', y='Criticrating', 
                 fill=True, cmap='inferno', ax=axes[0, 1])
k2b = sns.kdeplot(data=data, x='BudgetMillions', y='Criticrating', 
                  cmap='cool', ax=axes[0, 1])

# Plot [1,0] - Violin plot
z = sns.violinplot(data=data[data.Genre == 'Drama'], 
                   x='Year', y='Criticrating', ax=axes[1, 0])

# Plot [1,1]
k4 = sns.kdeplot(data=data, x='Criticrating', y='AudienceRating', 
                 fill=True, cmap='Blues_r', ax=axes[1, 1])
k4b = sns.kdeplot(data=data, x='Criticrating', y='AudienceRating', 
                  cmap='gist_gray_r', ax=axes[1, 1])

# Set limits
axes[0, 0].set(xlim=(-20, 160))
axes[0, 1].set(xlim=(-20, 160))

plt.show()
